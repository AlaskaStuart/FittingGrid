# %% [markdown]
# ![1_drill_location_pts](./1_drill_location_pts.png)
# ![2_hough_transform](./2_hough_transform.png)
# ![3_hough_transform_pts](./3_hough_transform_pts.png)
# ![4_kde_whole_region](./4_kde_whole_region.png)
# ![5_kde_whole_region_3d](./5_kde_whole_region_3d.png)
# ![6_kde_left_region](./6_kde_left_region.png)
# ![7_kde_left_region_3d](./7_kde_left_region_3d.png)
# ![8_kde_right_region](./8_kde_right_region.png)
# ![9_kde_right_region_3d](./9_kde_right_region_3d.png)
